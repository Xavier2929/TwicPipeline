# %% [markdown]
# <h4> Merging to megadata base </h4>
# - Get all the twic pgn files and merge it into the main pgn file, if the main pgn file doesn't exists, then let this first pgn files combined, be the main pgn file.

# %%
import os
import chess.pgn

# %%
twic_folder = os.getenv("TWIC_FILES_FOLDER")
display(twic_folder)
# Out:
# 'src/twic-files/'

# %%
# games_collection = []

# for file in os.listdir(twic_folder):
#     print(file)
#     with open(os.path.join(twic_folder,file),encoding='utf-8',errors='ignore') as pgn:
#         while True:
#             game = chess.pgn.read_game(pgn)
#             if game is None:
#                 break
#             games_collection.append(game)
            
#display(games_collection)

# %%
output_dir = os.getenv("COMBINED_TWIC_FOLDER")
os.makedirs(output_dir, exist_ok=True)

output_file = os.path.join(output_dir, "combined.pgn")

# 👇 append si existe / create si no existe
with open(output_file, "a", encoding="utf-8") as outfile:
    for filename in sorted(os.listdir(twic_folder)):
        if filename.lower().endswith(".pgn"):
            print("Agregando:", filename)
            file_path = os.path.join(twic_folder, filename)

            with open(file_path, "r", encoding="utf-8", errors="ignore") as infile:
                content = infile.read().strip()
                if content:  # evita agregar bloques vacíos
                    outfile.write("\n\n")  # separador PGN
                    outfile.write(content)

print("PGNS combined (append):", output_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 8
#       6 # 👇 append si existe / create si no existe
#       7 with open(output_file, "a", encoding="utf-8") as outfile:
# ----> 8     for filename in sorted(os.listdir(twic_folder)):
#       9         if filename.lower().endswith(".pgn"):
#      10             print("Agregando:", filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'src/twic-files/'
